# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\smart\Desktop\new\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop(columns = "Not_Useful_Column" )
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
#df["Last_Name"] = df["Last_Name"].str.lstrip("..")
#df["Last_Name"] = df["Last_Name"].str.lstrip("/")
#df["Last_Name"] = df["Last_Name"].str.rstrip("_")
df["Last_Name"] = df["Last_Name"].str.strip("..._/")
df
# Out:
# C:\Users\smart\AppData\Local\Temp\ipykernel_232\384000953.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].str.strip("..._/")
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# ...

# %%
#df["Phone_Number"] = df["Phone_Number"].str.replace("[^a-ZA-ZO-9]", "")
#df["Phone_Number"].apply(lambda x: x[0:3]+ "-" + x[3:6]+ "-" + x[6:10])
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
#df["Phone_Number"].apply(lambda x: x[0:3]+ "-" + x[3:6]+ "-" + x[6:10])
df['Phone_Number'] = df['Phone_Number'].str.replace('|', '')
df
# Out:
# C:\Users\smart\AppData\Local\Temp\ipykernel_232\500411656.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].str.replace('|', '')
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White           NaN
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow    8766783469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes    8766783469
# 8         1009    Gandalf         NaN           N/a
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace(r'(\d{3})(?=\d)', r'\1-', regex=True)
df
# Out:
# C:\Users\smart\AppData\Local\Temp\ipykernel_232\1864630383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].str.replace(r'(\d{3})(?=\d)', r'\1-', regex=True)
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-542-1
# 1         1002       Abed       Nadir  123/643/977-5
# 2         1003     Walter       White            NaN
# 3         1004     Dwight     Schrute  123-543-234-5
# 4         1005        Jon        Snow  876-678-346-9
# 5         1006        Ron     Swanson  304-762-246-7
# 6         1007       Jeff      Winger            NaN
# 7         1008   Sherlock      Holmes  876-678-346-9
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-542-1
# 1         1002       Abed       Nadir  123/643/977-5
# 2         1003     Walter       White            NaN
# 3         1004     Dwight     Schrute  123-543-234-5
# 4         1005        Jon        Snow  876-678-346-9
# 5         1006        Ron     Swanson  304-762-246-7
# 6         1007       Jeff      Winger            NaN
# 7         1008   Sherlock      Holmes  876-678-346-9
# 8         1009    Gandalf         NaN            N/a
# 9         1010      Peter      Parker  123-545-542-1
# 10        1011    Samwise      Gamgee            NaN
# 11        1012      Harry      Potter            NaN
# 12        1013        Don      Draper  123-543-234-5
# 13        1014     Leslie       Knope  876-678-346-9
# 14        1015       Toby  Flenderson  304-762-246-7
# 15        1016        Ron     Weasley  123-545-542-1
# 16        1017   Michael        Scott  123/643/977-5
# ...

# %%
df["Phone_Number"] = df['Phone_Number'].str.replace('Na','')
df
# Out:
# C:\Users\smart\AppData\Local\Temp\ipykernel_232\4153811049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df['Phone_Number'].str.replace('Na','')
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-542-1
# 1         1002       Abed       Nadir  123/643/977-5
# 2         1003     Walter       White            NaN
# 3         1004     Dwight     Schrute  123-543-234-5
# 4         1005        Jon        Snow  876-678-346-9
# 5         1006        Ron     Swanson  304-762-246-7
# 6         1007       Jeff      Winger            NaN
# 7         1008   Sherlock      Holmes  876-678-346-9
# 8         1009    Gandalf         NaN            N/a
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].fillna(" ")
df
# Out:
# C:\Users\smart\AppData\Local\Temp\ipykernel_7528\3835146203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].fillna(" ")
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-542-1
# 1         1002       Abed       Nadir  123-643-977-5
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-234-5
# 4         1005        Jon        Snow  876-678-346-9
# 5         1006        Ron     Swanson  304-762-246-7
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-346-9
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-542-1
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-542-1
# 1         1002       Abed       Nadir  123/643/977-5
# 2         1003     Walter       White            NaN
# 3         1004     Dwight     Schrute  123-543-234-5
# 4         1005        Jon        Snow  876-678-346-9
# 5         1006        Ron     Swanson  304-762-246-7
# 6         1007       Jeff      Winger            NaN
# 7         1008   Sherlock      Holmes  876-678-346-9
# 8         1009    Gandalf         NaN            N/a
# 9         1010      Peter      Parker  123-545-542-1
# 10        1011    Samwise      Gamgee            NaN
# 11        1012      Harry      Potter            NaN
# 12        1013        Don      Draper  123-543-234-5
# 13        1014     Leslie       Knope  876-678-346-9
# 14        1015       Toby  Flenderson  304-762-246-7
# 15        1016        Ron     Weasley  123-545-542-1
# 16        1017   Michael        Scott  123/643/977-5
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-542-1
# 1         1002       Abed       Nadir  123/643/977-5
# 2         1003     Walter       White            NaN
# 3         1004     Dwight     Schrute  123-543-234-5
# 4         1005        Jon        Snow  876-678-346-9
# 5         1006        Ron     Swanson  304-762-246-7
# 6         1007       Jeff      Winger            NaN
# 7         1008   Sherlock      Holmes  876-678-346-9
# 8         1009    Gandalf         NaN            N/a
# 9         1010      Peter      Parker  123-545-542-1
# 10        1011    Samwise      Gamgee            NaN
# 11        1012      Harry      Potter            NaN
# 12        1013        Don      Draper  123-543-234-5
# 13        1014     Leslie       Knope  876-678-346-9
# 14        1015       Toby  Flenderson  304-762-246-7
# 15        1016        Ron     Weasley  123-545-542-1
# 16        1017   Michael        Scott  123/643/977-5
# ...

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] =="Y":
        df.drop(x, inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name   Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-542-1
# 1         1002       Abed       Nadir  123/643/977-5
# 2         1003     Walter       White            NaN
# 4         1005        Jon        Snow  876-678-346-9
# 5         1006        Ron     Swanson  304-762-246-7
# 6         1007       Jeff      Winger            NaN
# 7         1008   Sherlock      Holmes  876-678-346-9
# 8         1009    Gandalf         NaN            N/a
# 9         1010      Peter      Parker  123-545-542-1
# 10        1011    Samwise      Gamgee            NaN
# 11        1012      Harry      Potter            NaN
# 12        1013        Don      Draper  123-543-234-5
# 13        1014     Leslie       Knope  876-678-346-9
# 14        1015       Toby  Flenderson  304-762-246-7
# 15        1016        Ron     Weasley  123-545-542-1
# 16        1017   Michael        Scott  123/643/977-5
# 17        1018      Clark        Kent            NaN
# ...
