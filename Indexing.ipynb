# %%
import pandas as pd

# %%
df2 = pd.read_excel(r"C:\Users\smart\Desktop\jupyter\world_population_excel_workbook.xlsx")
df2
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df2 = pd.read_excel(r"C:\Users\smart\Desktop\jupyter\world_population_excel_workbook.xlsx", index_col = "Country")
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH         El AaiÃºn    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df2.reset_index(inplace=True)
df2
# Out:
#      index            Country  Rank CCA3           Capital Continent  \
# 0        0        Afghanistan    36  AFG             Kabul      Asia
# 1        1            Albania   138  ALB            Tirana    Europe
# 2        2            Algeria    34  DZA           Algiers    Africa
# 3        3     American Samoa   213  ASM         Pago Pago   Oceania
# 4        4            Andorra   203  AND  Andorra la Vella    Europe
# ..     ...                ...   ...  ...               ...       ...
# 229    229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230    230     Western Sahara   172  ESH         El AaiÃºn    Africa
# 231    231              Yemen    46  YEM             Sanaa      Asia
# 232    232             Zambia    63  ZMB            Lusaka    Africa
# 233    233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
df2.loc["Algeria"]
# Out:
# level_0                               2
# index                                 2
# Rank                                 34
# CCA3                                DZA
# Capital                         Algiers
# Continent                        Africa
# 2022 Population                44903225
# 2020 Population                43451666
# 2015 Population                39543154
# 2010 Population                35856344
# 2000 Population                30774621
# 1990 Population                25518074
# 1980 Population                18739378
# 1970 Population                13795915
# Area (kmÂ²)                     2381741
# Density (per kmÂ²)              18.8531
# Growth Rate                      1.0164
# World Population Percentage        0.56
# Name: Algeria, dtype: object

# %%
df2.iloc[3]
# Out:
# level_0                                3
# index                                  3
# Rank                                 213
# CCA3                                 ASM
# Capital                        Pago Pago
# Continent                        Oceania
# 2022 Population                    44273
# 2020 Population                    46189
# 2015 Population                    51368
# 2010 Population                    54849
# 2000 Population                    58230
# 1990 Population                    47818
# 1980 Population                    32886
# 1970 Population                    27075
# Area (kmÂ²)                          199
# Density (per kmÂ²)              222.4774
# Growth Rate                       0.9831
# World Population Percentage          0.0
# Name: American Samoa, dtype: object

# %%
df2.set_index(["Continent","Country"],inplace=True)

# %%
df2
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul         41128771
# Europe    Albania             138  ALB            Tirana          2842321
# Africa    Algeria              34  DZA           Algiers         44903225
# Oceania   American Samoa      213  ASM         Pago Pago            44273
# Europe    Andorra             203  AND  Andorra la Vella            79824
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu            11572
# Africa    Western Sahara      172  ESH         El AaiÃºn           575986
# Asia      Yemen                46  YEM             Sanaa         33696614
# Africa    Zambia               63  ZMB            Lusaka         20017675
#           Zimbabwe             74  ZWE            Harare         16320537
#
# ...

# %%
df2.sort_index()

#pd.set_option("display.max.rows",235)
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH         El AaiÃºn    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df2.loc["Africa","Angola"]
# Out:
# Rank                                 42
# CCA3                                AGO
# Capital                          Luanda
# 2022 Population                35588987
# 2020 Population                33428485
# 2015 Population                28127721
# 2010 Population                23364185
# 2000 Population                16394062
# 1990 Population                11828638
# 1980 Population                 8330047
# 1970 Population                 6029700
# Area (kmÂ²)                     1246700
# Density (per kmÂ²)              28.5466
# Growth Rate                      1.0315
# World Population Percentage        0.45
# Name: (Africa, Angola), dtype: object

# %%
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH         El AaiÃºn    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df2.set_index(["Capital","Capital"])
#df2.reset_index(inplace=True)
#df2
# Out:
#                                    index            Country  Rank CCA3  \
# Capital          Capital
# Kabul            Kabul                 0        Afghanistan    36  AFG
# Tirana           Tirana                1            Albania   138  ALB
# Algiers          Algiers               2            Algeria    34  DZA
# Pago Pago        Pago Pago             3     American Samoa   213  ASM
# Andorra la Vella Andorra la Vella      4            Andorra   203  AND
# ...                                  ...                ...   ...  ...
# Mata-Utu         Mata-Utu            229  Wallis and Futuna   226  WLF
# El AaiÃºn        El AaiÃºn           230     Western Sahara   172  ESH
# Sanaa            Sanaa               231              Yemen    46  YEM
# Lusaka           Lusaka              232             Zambia    63  ZMB
# Harare           Harare              233           Zimbabwe    74  ZWE
#
#                                   Continent  2022 Population  2020 Population  \
# ...
